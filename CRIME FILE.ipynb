# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
crime=pd.read_csv(r"C:\Users\salma\Downloads\archive (12)\crimes_against_women_2001-2014.csv")

# %%
crime
# Out:
#        Unnamed: 0        STATE/UT           DISTRICT  Year  Rape  \
# 0               0  ANDHRA PRADESH           ADILABAD  2001    50
# 1               1  ANDHRA PRADESH          ANANTAPUR  2001    23
# 2               2  ANDHRA PRADESH           CHITTOOR  2001    27
# 3               3  ANDHRA PRADESH           CUDDAPAH  2001    20
# 4               4  ANDHRA PRADESH      EAST GODAVARI  2001    23
# ...           ...             ...                ...   ...   ...
# 10672         832     Lakshadweep        Lakshadweep  2014     1
# 10673         833     Lakshadweep  Total District(s)  2014     1
# 10674         834      Puducherry           Karaikal  2014     3
# 10675         835      Puducherry         Puducherry  2014     7
# 10676         836      Puducherry  Total District(s)  2014    10
#
#        Kidnapping and Abduction  Dowry Deaths  \
# 0                            30            16
# 1                            30             7
# ...

# %% [markdown]
# # introdction
# This data presentation focuses on the alarming statistics related to crimes against women across various states and union territories in India, highlighting trends and patterns from 2001 to 2014

# %% [markdown]
# # checking null values

# %%
crime.isnull().sum()
# Out:
# Unnamed: 0                                             0
# STATE/UT                                               0
# DISTRICT                                               0
# Year                                                   0
# Rape                                                   0
# Kidnapping and Abduction                               0
# Dowry Deaths                                           0
# Assault on women with intent to outrage her modesty    0
# Insult to modesty of Women                             0
# Cruelty by Husband or his Relatives                    0
# Importation of Girls                                   0
# dtype: int64

# %% [markdown]
# # checking duplicates

# %%
crime.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Visualizations

# %% [markdown]
# ### Top 10 States with Highest Rape Incidents

# %%
state=crime.groupby('STATE/UT')['Rape'].sum().sort_values(ascending=False).head(10)
state
# Out:
# STATE/UT
# MADHYA PRADESH    72174
# WEST BENGAL       41574
# UTTAR PRADESH     38116
# MAHARASHTRA       35972
# ASSAM             32356
# RAJASTHAN         31596
# ANDHRA PRADESH    26958
# BIHAR             26248
# CHHATTISGARH      23676
# ODISHA            22860
# Name: Rape, dtype: int64

# %%
state.plot(kind='bar', color='purple', figsize=(8,6))
plt.title('Top 10 States with Highest Rape Incidents')
plt.xlabel('State/UT')
plt.ylabel('Number of Rape Incident')
plt.show()

# %% [markdown]
# - **Madhya Pradesh has consistently reported the highest number of rape incidents among all states, raising serious concerns about the safety and security of women in the region.**
# - **This alarming statistic suggests that there are systemic issues contributing to violence against women.**

# %% [markdown]
# ### Top 10 States with Highest Kidnapping and Abduction Incidents

# %%
state_kidnapping_totals = crime.groupby('STATE/UT')['Kidnapping and Abduction'].sum().sort_values(ascending=False)
state_kidnapping_totals
# Out:
# STATE/UT
# UTTAR PRADESH    95180
# RAJASTHAN        49342
# ASSAM            45840
# WEST BENGAL      43546
# Uttar Pradesh    40726
#                  ...
# MIZORAM             20
# Daman & Diu         14
# Mizoram             10
# LAKSHADWEEP          2
# Lakshadweep          0
# Name: Kidnapping and Abduction, Length: 72, dtype: int64

# %%
state_kidnapping_totals.head(10).plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8), startangle=90)
plt.title('Top 10 States with Highest Kidnapping and Abduction Incidents')
plt.ylabel('')  
plt.show()

# %% [markdown]
# - **Uttar Pradesh has the highest number of kidnapping and abduction incidents in India.**

# %% [markdown]
# # Top 10 States with Highest Dowry Deaths

# %%
state_dowry_deaths = crime.groupby('STATE/UT')['Dowry Deaths'].sum().sort_values(ascending=False).head(10)
state_dowry_deaths
# Out:
# STATE/UT
# UTTAR PRADESH     47648
# BIHAR             27096
# MADHYA PRADESH    18072
# ANDHRA PRADESH    12430
# WEST BENGAL       10344
# RAJASTHAN         10132
# Uttar Pradesh      9608
# ODISHA             9110
# MAHARASHTRA        8498
# JHARKHAND          6582
# Name: Dowry Deaths, dtype: int64

# %%
state_dowry_deaths.head(10).plot(kind='bar', color='red', figsize=(10,6))
#plt.title('Top 10 States with Highest Dowry Deaths')
plt.xlabel('State/UT')
plt.ylabel('Number of Dowry Deaths')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - **Uttar Pradesh has the highest number of dowry deaths in India, indicating a serious violation of women's rights and a critical public safety issue that demands immediate attention**

# %% [markdown]
# # Top 10 States with Cruelty by Husband or Relatives Incidents

# %%
state_cruelty = crime.groupby('STATE/UT')['Cruelty by Husband or his Relatives'].sum().sort_values(ascending=False)
state_cruelty
# Out:
# STATE/UT
# WEST BENGAL       261336
# ANDHRA PRADESH    238014
# RAJASTHAN         200202
# MAHARASHTRA       160726
# UTTAR PRADESH     155234
#                    ...
# D&N Haveli            14
# LAKSHADWEEP           14
# Nagaland              14
# Daman & Diu            6
# Lakshadweep            0
# Name: Cruelty by Husband or his Relatives, Length: 72, dtype: int64

# %%
state_cruelty.head(10).plot(kind='bar', color='brown', figsize=(10,6))
#plt.title('Top 10 States with Cruelty by Husband or Relatives Incidents')
plt.xlabel('State/UT')
plt.ylabel('Number of Cruelty Incidents')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - **West Bengal has the highest number of cruelty incidents by husbands or relatives in India, indicating a pressing concern for women's safety and rights within domestic settings.**

# %% [markdown]
# # Suggestions to address crime against womens

# %% [markdown]
# - **Update Laws: Revise existing laws and introduce new legislation to ensure that crimes against women are addressed comprehensively and effectively.**
# - **Fast-Track Courts: Establish special courts to handle cases of violence against women quickly and efficiently, reducing the backlog of cases.**
# - **Helplines and Counseling: Establish dedicated helplines and counseling services to provide immediate support for victims of violence.**
#
# - **Safe Shelters: Create safe shelters for women fleeing abusive situations, offering them protection and resources for rebuilding their lives.**
